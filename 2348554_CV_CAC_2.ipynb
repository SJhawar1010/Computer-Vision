# %% [markdown]
# <a href="https://colab.research.google.com/github/SJhawar1010/Computer-Vision/blob/main/2348554_CV_CAC_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from google.colab.patches import cv2_imshow
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('/content/drive/MyDrive/CV_images/avengerexam.jpeg')

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=299x168>

# %%
print('Image Width is',image.shape[1])
print('Image Height is',image.shape[0])
# Out:
# Image Width is 299
# Image Height is 168

# %%
img_negative = image - 255

# %%
plt.imshow(img_negative, cmap='gray')
plt.title('Image Negative')
# Out:
# Text(0.5, 1.0, 'Image Negative')

# %%
img_8bit = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
hist_eq = cv2.equalizeHist(img_8bit)

# %%
plt.hist(image.flatten(), bins=256, range=[0, 256], color='black', alpha=0.7)
plt.title('Original Image Histogram')
# Out:
# Text(0.5, 1.0, 'Original Image Histogram')

# %%
plt.imshow(hist_eq, cmap='gray')
plt.title('Histogram Equalization')
# Out:
# Text(0.5, 1.0, 'Histogram Equalization')

# %%
plt.hist(hist_eq.flatten(), bins=256, range=[0, 256], color='black', alpha=0.7)
plt.title('Equalized Image Histogram')
# Out:
# Text(0.5, 1.0, 'Equalized Image Histogram')

# %%
imggray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
lt = 100
ut = 200
sliced_image = np.zeros_like(imggray)
for i in range(imggray.shape[0]):
    for j in range(imggray.shape[1]):
        pixel_value = imggray[i, j]
        if lt <= pixel_value <= ut:
            sliced_image[i, j] = 255
        else:
            sliced_image[i, j] = 0

# %%
cv2_imshow(sliced_image)
# Out:
# <PIL.Image.Image image mode=L size=299x168>

# %%
gbk = np.array([[1, 4, 6, 4, 1],
                             [4, 16, 24, 16, 4],
                             [6, 24, 20, 24, 6],
                             [4, 16, 24, 16, 4],
                             [1, 4, 6, 4, 1]])/256

# %%
img = cv2.resize(image, (500,300))

# %%
gbimage = cv2.filter2D(src=img, ddepth=-1, kernel=gbk)

# %%
cv2_imshow(gbimage)
# Out:
# <PIL.Image.Image image mode=RGB size=500x300>

# %%
lap = cv2.Laplacian(imggray, cv2.CV_64F)

# %%
lap = np.uint8(np.absolute(lap))

# %%
cv2_imshow(lap)
# Out:
# <PIL.Image.Image image mode=L size=500x300>
