# %% [markdown]
# <a href="https://colab.research.google.com/github/SJhawar1010/Computer-Vision/blob/main/2348554_CV_Extra_Program_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('/content/drive/MyDrive/CV_images/avg1.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>

# %%
img_color = cv2.imread('/content/drive/MyDrive/CV_images/avg1.jpg',1)
img_grayscale = cv2.imread('/content/drive/MyDrive/CV_images/avg1.jpg',0)
img_unchanged = cv2.imread('/content/drive/MyDrive/CV_images/avg1.jpg',-1)

# %%
cv2_imshow(img_color)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>

# %%
cv2_imshow(img_grayscale)
# Out:
# <PIL.Image.Image image mode=L size=300x168>

# %%
cv2_imshow(img_unchanged)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>

# %%
cv2.imwrite('grayscale.png',img_grayscale)
# Out:
# True

# %%
import imageio as iio

# %%
img = iio.imread('/content/drive/MyDrive/CV_images/avg2.jpg')
# Out:
# <ipython-input-81-4ddfd30fa147>:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = iio.imread('/content/drive/MyDrive/CV_images/avg2.jpg')

# %%
iio.imwrite("The_Avengers.png", img)

# %%
print(img.shape)
# Out:
# (168, 300, 3)

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img = mpimg.imread('The_Avengers.png')
plt.imshow(img)

# %%
print(img.shape)
# Out:
# (168, 300, 3)

# %%
modifiedImage = img[:, :, 0]
plt.imshow(modifiedImage)

# %%
plt.imshow(modifiedImage, cmap="hot")

# %%
imgplot = plt.imshow(modifiedImage)
imgplot.set_cmap('nipy_spectral')

# %%
imgplot = plt.imshow(modifiedImage)
plt.colorbar()

# %%
img = mpimg.imread("The_Avengers.png")

plt.imshow(img)

# %%
from PIL import Image

# %%
img = Image.open('/content/drive/MyDrive/CV_images/avg.jpg')

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=183x275>

# %%
print("Filename: ", img.filename)
print("Image Format: ",img.format)
print("Image Mode: ",img.mode)
print("Width: ", img.width)
print("Height: ", img.height)
print("Size: ", img.size)
# Out:
# Filename:  /content/drive/MyDrive/CV_images/avg.jpg
# Image Format:  JPEG
# Image Mode:  RGB
# Width:  183
# Height:  275
# Size:  (183, 275)

# %%
img = img.save("heroes.tif")

# %%
display(img)
# Out:
# None
